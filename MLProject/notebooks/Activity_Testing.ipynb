# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array

model = tf.keras.models.load_model("activity_model.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# Example: replace with your actual classes
class_names = ['calling', 'clapping', 'cycling', 'drinking', 'eating', 'fighting', 'happy', 'jumping', 'laptop', 'running', 'sitting', 'sleeping', 'walking']

def predict(img_path):
    img = load_img(img_path, target_size=(224, 224))
    arr = img_to_array(img) / 255.0
    arr = np.expand_dims(arr, axis=0)

    pred = model.predict(arr)[0]
    cls = np.argmax(pred)
    confidence = pred[cls]

    return class_names[cls], confidence

# %%
import os

img_path = "C:/Users/Umer/Desktop/AiProject/dataset/sitting/sitting_1.jpg"
print(os.path.exists(img_path))  # Should print True
# Out:
# True

# %%
# img_path = "dataset/walking/walking_1.jpg"
img_path = "C:/Users/Umer/Desktop/AiProject/dataset/sitting/sitting_1.jpg"

label, conf = predict(img_path)

print("Predicted:", label)
print("Confidence:", conf)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Predicted: sitting
# Confidence: 0.89270395
